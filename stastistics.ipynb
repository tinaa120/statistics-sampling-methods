# %% [markdown]
# STATISTICS ASSIGNMENT 1

# %% [markdown]
# Laxmi(22bcs059)

# %% [markdown]
# data-  Healthcare_dataset

# %%
import pandas as pd
csv_1=pd.read_csv("C:\\Users\\DELL G15\\Desktop\\statistics\\healthcare_dataset 1.csv")
csv_1
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %% [markdown]
# Probability (Random) Sampling Methods:

# %% [markdown]
# 1. Simple Random Sampling:

# %% [markdown]
# code for this

# %%
n_samples = 10

simple_random_sample = csv_1.sample(n=n_samples, random_state=1)  

print(simple_random_sample)
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 32354      MichAel MILLs   63    Male         O-            Cancer
# 46537    wiLlIam RAmirEz   81  Female         B-            Asthma
# 34234       JosEph MeYER   51    Male        AB-         Arthritis
# 54136  DR. micHaEl MckAy   64    Male         O+            Cancer
# 16406   MoNiCA CaRpEnTER   72    Male         O+          Diabetes
# 45858        ERIC HuRLey   53    Male         A+         Arthritis
# 11578    daNieLle hAYNES   57  Female         O+            Cancer
# 50172       NICole HeNrY   73  Female         A+           Obesity
# 36796        raCHAel LeE   36  Female        AB-      Hypertension
# 487           ANn dUNCAN   24    Male         A-            Asthma
#
#       Date of Admission             Doctor                     Hospital  \
# 32354        2023-06-30      Ronald Gordon              Weber-Mcpherson
# 46537        2022-09-17   Christian Galvan                Murphy-French
# ...

# %% [markdown]
# .

# %% [markdown]
# 2. Systematic Sampling:

# %% [markdown]
# code for this

# %%
def systematic_sampling(csv_1, k):
    return csv_1.iloc[::k]

k = 5000
systematic_sample = systematic_sampling(csv_1, k)

print(systematic_sample)
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0            Bobby JacksOn   30    Male         B-            Cancer
# 5000         AshlEy gORDon   22  Female         A+         Arthritis
# 10000         jOsePH JOnes   33  Female         O-            Cancer
# 15000             Amy COOK   47  Female         O-            Asthma
# 20000       TERry hAmIltOn   66  Female         O-           Obesity
# 25000        derRiCk joNes   35    Male         A+         Arthritis
# 30000  AnthOnY MOnToYA PhD   81    Male        AB+            Asthma
# 35000          anItA dAVIS   62    Male         A-            Asthma
# 40000      dAniEl AnDerSON   22    Male        AB+           Obesity
# 45000        stEVeN hunteR   55    Male        AB+          Diabetes
# 50000        KRISTa GiBsoN   24    Male         A+          Diabetes
# 55000        RODNey tRavIS   41  Female         B-            Cancer
#
# ...

# %% [markdown]
# .

# %% [markdown]
# ## 3. Stratified Sampling:

# %% [markdown]
# code for this

# %% [markdown]
# for example : Stratify by 'Gender'

# %%
n_samples_per_stratum = 5


stratified_sample = (
    csv_1.groupby('Gender', group_keys=False)
    .apply(lambda x: x.sample(n=min(n_samples_per_stratum, len(x)), random_state=1))
    .reset_index(drop=True)  # Optionally reset the index to avoid group keys issues
)

print(stratified_sample)
# Out:
#                Name  Age  Gender Blood Type Medical Condition  \
# 0   HEAthER fIScHEr   70  Female         O-           Obesity
# 1      AbIgail rUsh   65  Female         O-            Asthma
# 2      DaViD BUrtoN   31  Female         B+      Hypertension
# 3     SuZaNNE maRSh   37  Female        AB+            Cancer
# 4     regINa carTer   25  Female        AB+            Asthma
# 5  chriStINa mILlER   73    Male         A+      Hypertension
# 6     miCHELE KElLy   26    Male        AB+            Asthma
# 7       nancy moORE   41    Male        AB-         Arthritis
# 8     dONALd gaRcIa   52    Male         A-            Cancer
# 9    James WIlLIaMs   46    Male         A-            Cancer
#
#   Date of Admission               Doctor                       Hospital  \
# 0        2019-07-12          James Brown                  PLC Castaneda
# 1        2019-05-11       Casey Robinson   Cordova Williams Nguyen, and
# ...

# %% [markdown]
# .

# %% [markdown]
# ## 4.CLUSTER SAMPLING

# %% [markdown]
# Code for this :
# <br> Cluster Definition: Each unique hospital in the dataset represents a distinct cluster.
# <br>  Random Selection: A random sample of hospitals (clusters) is chosen to form the final sample.
# <br>  Complete Inclusion: All individuals from the selected hospitals are included in the sample, ensuring comprehensive representation from the sampled clusters.

# %%
import numpy as np 

num_clusters = 20  


clusters = csv_1['Hospital'].unique()
sampled_clusters = np.random.choice(clusters, num_clusters, replace=False)  
cluster_sample = csv_1[csv_1['Hospital'].isin(sampled_clusters)]  

print(cluster_sample)
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 3498        KeLSey JaMES   38  Female         A-            Cancer
# 5763         aLAn dAwSon   52  Female         O+            Cancer
# 8221    DebRA richARdsOn   22    Male        AB+           Obesity
# 11461   ChrIsTINa NelsOn   72  Female         O-           Obesity
# 13161        emILy browN   24  Female        AB+      Hypertension
# 13845      RobERt NguYEN   22    Male        AB+      Hypertension
# 15012      Kevin SANChEz   34  Female         O+      Hypertension
# 16373      TiMOTHY HObBs   36  Female         A+           Obesity
# 18843       EMIly MartiN   61    Male         B+            Cancer
# 20109    HEaTheR StEvENS   78  Female         A+         Arthritis
# 20703        brenDA bESt   72    Male         B+          Diabetes
# 25805  cHRIStIAn cArlsoN   44  Female         O-            Cancer
# 26463    jennifer PaRKer   83    Male         A-           Obesity
# ...

# %% [markdown]
# .

# %% [markdown]
#  # Non probability sampling methods:

# %% [markdown]
# ## 1.CONVENIENCE SAMPLING

# %% [markdown]
# code for this

# %%
n_samples = 55 
convenience_sample = csv_1.head(n_samples)

print(convenience_sample)
# Out:
#                    Name  Age  Gender Blood Type Medical Condition  \
# 0         Bobby JacksOn   30    Male         B-            Cancer
# 1          LesLie TErRy   62    Male         A+           Obesity
# 2           DaNnY sMitH   76  Female         A-           Obesity
# 3          andrEw waTtS   28  Female         O+          Diabetes
# 4         adrIENNE bEll   43  Female        AB+            Cancer
# 5         EMILY JOHNSOn   36    Male         A+            Asthma
# 6        edwArD EDWaRDs   21  Female        AB-          Diabetes
# 7    CHrisTInA MARtinez   20  Female         A+            Cancer
# 8       JASmINe aGuIlaR   82    Male        AB+            Asthma
# 9      ChRISTopher BerG   58  Female        AB-            Cancer
# 10     mIchElLe daniELs   72    Male         O+            Cancer
# 11       aaRon MARtiNeZ   38  Female         A-      Hypertension
# 12        connOR HANsEn   75  Female         A+          Diabetes
# ...

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# ## 2. PURPOSIVE SAMPLING

# %% [markdown]
# CODE FOR THIS

# %% [markdown]
# Purposive Sampling Based on Medical Condition

# %%
csv_1.head()

medical_condition_of_interest = 'Diabetes'  


purposive_sample_condition = csv_1[csv_1['Medical Condition'] == medical_condition_of_interest]


purposive_sample_condition.head()
# Out:
#                  Name  Age  Gender Blood Type Medical Condition  \
# 3        andrEw waTtS   28  Female         O+          Diabetes
# 6      edwArD EDWaRDs   21  Female        AB-          Diabetes
# 12      connOR HANsEn   75  Female         A+          Diabetes
# 27  mr. KenNEth MoORE   34  Female         A+          Diabetes
# 34   NicOlE RodriGUEz   30  Female        AB+          Diabetes
#
#    Date of Admission            Doctor                    Hospital  \
# 3         2020-11-18       Kevin Wells  Hernandez Rogers and Vang,
# 6         2020-11-03       Kelly Olson             Group Middleton
# 12        2019-12-12  Kenneth Fletcher   Powers Miller, and Flores
# 27        2022-06-21       James Ellis               Serrano-Dixon
# 34        2020-01-17        Lynn Young                   Poole Inc
#
#    Insurance Provider  Billing Amount  Room Number Admission Type  \
# 3            Medicare    37909.782410          450       Elective
# ...

# %% [markdown]
# ## 3.SNOWBALL SAMPLING

# %% [markdown]
# Code for this

# %% [markdown]
#  let’s assume we are starting with individuals who have a specific condition or are from a specific hospital.
# Here, we simulate the snowball sampling process. We'll assume that each participant in the sample can refer up to a specified number of additional participants.

# %%
print(csv_1.head())
print(csv_1.columns)

initial_condition = 'Diabetes'
initial_sample_size = 5

initial_sample = csv_1[csv_1['Medical Condition'] == initial_condition].head(initial_sample_size)

print("Initial Sample:")
print(initial_sample)

referral_limit = 10

all_sampled = set(initial_sample.index)

participants_to_process = list(initial_sample.index)

def refer_additional_participants(participant_indices, referral_limit):
    new_samples = set()
    for idx in participant_indices:
        participant_hospital = csv_1.loc[idx, 'Hospital']
        referrals = csv_1[csv_1['Hospital'] == participant_hospital]
        referrals = referrals[~referrals.index.isin(all_sampled)]
        new_samples.update(referrals.head(referral_limit).index)
    return new_samples

while participants_to_process:
    new_referrals = refer_additional_participants(participants_to_process, referral_limit)
    new_participants = new_referrals - all_sampled
    if not new_participants:
        break
    all_sampled.update(new_participants)
    participants_to_process = list(new_participants)

final_sample = csv_1.loc[list(all_sampled)]

print("Final Sample:")
print(final_sample)
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %% [markdown]
# .

# %% [markdown]
# # 4. JUDGMENT SAMPLING

# %% [markdown]
# Code for this: criteria for this is

# %% [markdown]
# 'Medical Condition': 'Diabetes'
# Example criterion
#     'Hospital': 'General Hospital'

# %%
print(csv_1.head())
print(csv_1.columns)


criteria = {
    'Medical Condition': 'Diabetes',  
    'Hospital': 'General Hospital'    
}

judgment_sample = csv_1[
    (csv_1['Medical Condition'] == criteria['Medical Condition']) & 
    (csv_1['Hospital'] == criteria['Hospital'])
]


print("Judgment Sample:")
print(judgment_sample)
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %% [markdown]
# End
